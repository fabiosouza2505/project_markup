# %%
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
import warnings
import fitz
import logging
import traceback
warnings.filterwarnings('ignore')

class IPASectorMapper:
    """
    Classe para mapeamento e agregação de setores IPA
    """
    def __init__(self):
        # Mapeamento explícito para garantir consistência na agregação
        self.explicit_mapping = {
            ## AGROPECUÁRIA
            # Agriculta e pecuária
            '201101000': '2011010', # Agricultura
            '201101500': '2011010', # Pecuária
            ## INDÚSTRIA EXTRATIVA
            # Indústria extrativa, inclusive petróleo e gás natural
            '202106000': '2021060',  # Extração de Petróleo e gás natural
            '202107000': '2021060',  # Extração de minerais metálicos e não-metálicos
            '202107200': '2021060',  # Minerais metálicos e não-metálicos
            '202108000': '2021060',  # Minerais metálicos e não-metálicos
            ## INDÚSTRIA DE TRANSFORMAÇÃO
            # Alimentos e bebidas
            '202210100': '2022100',  # Carne e derivados
            '202210200': '2022100',  # Pescados
            '202210300': '2022100',  # Conservas de frutas, legumes e outros vegetais
            '202210400': '2022100',  # Óleos e gorduras vegetais
            '202210500': '2022100',  # Laticínios
            '202210600': '2022100',  # Produtos amiláceos e alimentos para animais
            '202210700': '2022100',  # Açúcar
            '202210800': '2022100',  # Café
            '202210900': '2022100',  # Outros produtos alimentícios
            '202211000': '2022100',  #Bebidas
            # Fumo processado e produtos do fumo
            # Têxteis, vestuário, couros e calçados
            '202213000': '2022130',  # Produtos Têxteis (fios, tecitos e artefatos têxteis)
            '202214000': '2022130',  # Artigos do vestuário
            '202215000': '2022130',  # Couro e calçados
            # Madeira, celulose e papel
            '202216000': '2022160',  # Madeira desdobrada e produtos de madeira
            '202217100': '2022160',  # Celulose
            '202217200': '2022160',  # Papel, cartolina e papel-cartão
            '202217300': '2022160',  # Embalagens de papel, papelão ondulado, cartolina e papel-cartão
            '202217900': '2022160',  # Indústria de celulose e produtos de papel e papelão
            '202217400': '2022160',  # Artefatos diversos de papel, cartolina e papel-cartão
            # Produtos derivados do petróleo e biocombustíveis
            '202219200': '2022190',  # Produtos derivados do petróleo
            '202219300': '2022190',  # Biocombustíveis
            '202219900': '2022190',  # Produtos derivados do petróleo e Biocombustíveis
            # Indústria química, exceto petroquímica
            '202220100': '2022200',  # Produtos químicos inorgânicos
            '202220200': '2022200',  # Produtos químicos orgânicos
            '202220300': '2022200',  # Resinas e elastômeros
            '202220400': '2022200',  # Fibras e filamentos sintéticos
            '202220500': '2022200',  # Defensivos agrícolas e desinfestantes domissanitários
            '202220600': '2022200',  # Produtos de limpeza, cosméticos e artigos de perfumaria e de higiene pessoal
            '202220700': '2022200',  # Tintas, vernizes, esmaltes, lacas e produtos afins
            '202220900': '2022200',  # Produtos e preparados químicos diversos
            # Produtos farmacêuticos
            '202221200': '2022210',  # Medicamentos
            # Artigos de borracha e de material plástico
            '202222100': '2022220',  # Artigos de borracha
            '202222200': '2022220',  # Produtos de material plástico
            # # Metalurgia e siderurgia e produtos de minerais não-metálicos
            '202223100': '2022240',  # Vidro e produtos de vidro
            '202223200': '2022240',  # Cimento
            '202223300': '2022240',  # Artefatos de concreto, cimento e fibrocimento
            '202223400': '2022240',  # Produtos cerâmicos
            '202223900': '2022240',  # Pedras, cal e outros produtos não-metálicos
            '202224100': '2022240',  # Ferro-gusa e ferro-ligas
            '202224200': '2022240',  # Produtos siderúrgicos
            '202224400': '2022240',  # Produtos da metalurgia dos não-ferrosos
            '202225300': '2022240',  # Forjados e estampados
            '202225900': '2022240',  # Produtos diversos de metal 
            # Máquinas, equipamentos e aparelhos diversos
            '202226200': '2022270',  # Computadores e Acessórios
            '202226300': '2022270',  # Equipamentos transmissores de comunicação e aparelhos telefônicos
            '202227100': '2022270',  # Geradores, transformadores e motores elétricos
            '202227200': '2022270',  # Pilhas, baterias e acumuladores
            '202227300': '2022270',  # Equipamentos para distribuição e controle de energia elétrica
            '202227500': '2022270',  # Eletrodomésticos
            '202227900': '2022270',  # Equipamentos e aparelhos elétricos diversos
            '202228100': '2022270',  # Motores, bombas, compressores e equipamentos de transmissão
            '202228200': '2022270',  # Máquinas e equipamentos de uso geral
            '202228300': '2022270',  # Máquinas e equipamentos para a agricultura
            '202228400': '2022270',  # Máquinas-ferramenta
            '202228500': '2022270',  # Máquinas e equipamentos de terraplenagem e pavimentação
            '202228600': '2022270',  # Máquinas e equipamentos de uso específico
            # Veículos automotores e e outros equipamentos de transporte
            '202229100': '2022290',  # Automóveis, camionetas e utilitários
            '202229200': '2022290',  # Caminhões e ônibus
            '202229300': '2022290',  # Cabines, carrocerias e reboques
            '202229400': '2022290',  # Peças e acessórios para veículos automotores
            '202230100': '2022290',  # Embarcações
            '202230300': '2022290',  # Veículos ferroviários
            '202230900': '2022290',  # Outros equipamentos de transporte
            # Móveis
            '202231100': '2022310'  # Moveis 
        }
        
        # Nomes dos setores de 7 dígitos
        self.sector_names = {
            '2011010': 'Agricultura e pecuária', 
            '2021060': 'Indústria extrativa, inclusive petróleo e gás natural',
            '2022100': 'Alimentos e bebidas',
            '2022130': 'Têxteis, vestuário, couro e calçados',
            '2022160': 'Madeira, celulose e papel',
            '2022190': 'Produtos derivados do petróleo e biocombustíveis',
            '2022200': 'Indústria química, exceto petroquímica',
            '2022210': 'Indústria farmacêutica',
            '2022220': 'Artigos de borracha e de material plástico',
            '2022240': 'Metalurgia, siderurgia e produtos de minerais não-metálicos',
            '2022270': 'Máquinas, equipamentos e aparelhos diversos',
            '2022290': 'Veículos automotores e e outros equipamentos de transporte',
            '2022310': 'Móveis'
        }

    def get_7digit_sector(self, code: str) -> str:
        """Agrega código IPA para o nível de 7 dígitos"""
        if not code:
            return None
            
        code_str = str(code)
        
        # Primeiro verifica o mapeamento explícito
        if code_str in self.explicit_mapping:
            return self.explicit_mapping[code_str]
            
        # Se não estiver no mapeamento explícito, trunca para 7 dígitos
        if len(code_str) >= 7:
            return code_str[:7]
            
        return code_str

    def get_sector_name(self, code: str) -> str:
        """Obtém o nome do setor"""
        sector_code = self.get_7digit_sector(code)
        return self.sector_names.get(sector_code, f"Setor {sector_code}")

class DataLoader:
    """
    Classe responsável pelo carregamento e preparação de dados 
    com mapeamento setorial abrangente
    """
    
    def __init__(self, base_dir, ipa_path):
        """
        Inicializa o DataLoader com configurações de mapeamento

        Args:
            base_dir (str): Diretório base dos dados
            ipa_path (str): Caminho para o arquivo de índices de preços
        """
        self.base_dir = Path(base_dir)
        self.ipa_path = Path(ipa_path)
        self.sector_mapper = IPASectorMapper()
        
        # Definição centralizada dos padrões de contas
        self.padroes_contas = {
            # Contas fundamentais
            'variaveis_base': {
                'receita': [
                    'Receita liquida', 'Receita Líquida', 
                    'Receita líquida operacional'
                ],
                'cogs': [
                    'Custo Produtos', 'Custo dos Produtos', 
                    'CPV', 'Custo Produtos Vendidos'
                ],
                'trabalho_indireto': [
                    'Despesas admin', 'Despesas administrativ', 
                    'Despesas Administrativas',
                    'Despesas com Vendas', 'Despesas de Vendas', 
                    'Despesas comerciais'
                ],
                'imobilizado': [
                    'Imobilizado', 'IMOBILIZADO', 
                    'Ativo Imobilizado'
                ]
            }
        }
        
        # Definição das colunas de descrição possíveis
        self.desc_cols = [
            'Consolidado', 'Descrição', 'Conta', 
            'Item', 'Demonstrativo'
        ]
    
        # Mapeamentos setoriais
              
        self.excecoes = {
            'ABEV': '202211000', #ok
            'AGRO': '201101000', #ok
            'AGXY': '201101000', #ok
            'APTI': '202224200', #ok
            'AURA': '202107200', #ok
            'BAUH': '202210100', #ok
            'BDLL': '202228300', #ok
            'BEEF': '202210100', #ok
            'BRFS': '202210100', #ok
            'BRAV': '202106000', #ok
            'BRKM': '202219200', #ok
            'CAML': '202210900', #ok
            'CBAV': '202224400', #ok
            'CMIN': '202107000', #ok
            'CRPG': '202220100', #ok
            'CSNA': '202224200', #ok
            'CTCA': '201101000', #ok
            'DXCO': '202216000', #ok
            'EALT': '202224200', #ok
            'EMBR': '202230100', #ok
            'ETER': '202223300', #ok
            'EUCA': '202216000', #ok
            'FESA': '202224200', #ok
            'FHER': '202220100', #ok
            'FRAS': '202229400', #ok
            'FRIO': '202228200', #ok
            'GGBR': '202224200', #ok
            'GOAU': '202224200', #ok
            'GRAO': '201101000', #ok
            'HAGA': '202224200', #ok
            'INEP': '202227900', #ok
            'JALL': '202210700', #ok
            'JBSS': '202210100', #ok
            'JOPA': '202210900', #ok
            'KEPL': '202225900', #ok
            'KLBN': '202217900', #ok
            'LAND': '201101000', #ok
            'LUPA': '202228200', #ok
            'MDIA': '202210900', #ok
            'MGEL': '202224200', #ok
            'MNPR': '202210100', #ok
            'MRFG': '202210100', #ok
            'MSPA': '202217900', #ok
            'MTSA': '202228300', #ok
            'MWET': '202229400', #ok
            'NEMO': '202217100', #ok
            'NORD': '202224200', #ok
            'NUTR': '202220500', #ok
            'ODER': '202210300', #ok
            'OPCT': '202219900', #ok
            'OSXB': '202106000', #ok
            'PATI': '202106000', #ok
            'PETR': '202106000', #ok
            'PMAM': '202224200', #ok
            'POMO': '202229300', #ok
            'PRIO': '202106000', #ok
            'PTBL': '202223400', #ok
            'PTCA': '202227500', #ok
            'RAIZ': '202219300', #ok
            'RANI': '202217300', #ok
            'RAPT': '202229300', #ok
            'RCSL': '202229300', #ok
            'RECV': '202106000', #ok
            'ROMI': '202228400', #ok
            'RPMG': '202219200', #ok
            'RSUL': '202229400', #ok
            'SHUL': '202228100', #ok
            'SLCE': '201101000', #ok
            'SMTO': '202210700', #OK
            'SOJA': '201101000', #ok
            'SUZB': '202217100', #ok
            'TASA': '202225900', #ok
            'TKNO': '202225300', #ok
            'TTEN': '201101000', #ok
            'TUPY': '202229400', #ok
            'UNIP': '202220100', #ok
            'USIM': '202224200', #ok
            'VALE': '202107000', #ok
            'VITT': '202220500', #ok
            'INTB': '202226200', #ok
            'MLAS': '202226200', #ok
            'POSI': '202226200', #ok
            'ALPA': '202215000', #ok
            'CAMB': '202215000', #ok
            'CATA': '202213000', #ok
            'CEDO': '202213000', #ok
            'CTKA': '202213000', #ok
            'CTNM': '202213000', #ok
            'CTSA': '202213000', #ok
            'DOHL': '202213000', #ok
            'GRND': '202214000', #ok
            'MNDL': '202214000', #ok
            'PTNT': '202213000', #ok
            'SGPS': '202213000', #ok
            'TECN': '202214000', #ok
            'TEKA': '202213000', #ok
            'TFCO': '202214000', #ok
            'TXRX': '202213000', #ok
            'VIVA': '202214000', #ok
            'VULC': '202215000', #ok
            'WEGE': '202228100', #ok
            'BALM': '202228600', #ok
            'LMED': '202228600', #ok
            'BIOM': '202221200', #ok
            'NRTQ': '202221200', #ok 
            'OFSA': '202221200', #ok
            'WHRL': '202226200' #ok
            
        }
        
        self.pesos_ipa = {
            '201101000': 0.181212,  # Agriculta
            '202107000': 0.131045,  # Minerais metálicos ferrosos e não-ferrosos
            '202107200': 0.010652,  # Minerais metálicos não-ferrosos
            '202108000': 0.010956,  # Minerais não-metálicos
            '202106000': 0.058258,  # Petróleo e gás natural
            '202210100': 0.050661,  # Produtos de carne e derivados
            '202210200': 0.000774,  # Pescados
            '202210300': 0.004601,  # Conservas de frutas, legumes e outros vegetais
            '202210400': 0.028220,  # Óleos e gorduras vegetais
            '202210500': 0.012823,  # Laticínios
            '202210600': 0.013287,  # Produtos amiláceos e alimentos para animais
            '202210700': 0.012911,  # Açúcar
            '202210800': 0.003840,  # Café
            '202210900': 0.013359,  # Outros produtos alimentícios
            '202211000': 0.015163,  # Bebidas
            '202213000': 0.001005,  # Produtos Têxteis (fios, tecitos e artefatos têxteis)
            '202214000': 0.005509,  # Artigos do vestuário
            '202215000': 0.004814,  # Couro e calçados
            '202216000': 0.004704,  # Madeira desdobrada e produtos de madeira
            '202217100': 0.006317,  # Celulose
            '202217200': 0.003306,  # Papel, cartolina e papel-cartão
            '202217300': 0.003717,  # Embalagens de papel, papelão ondulado, cartolina e papel-cartão
            '202217900': 0.013340,  # Indústria de celulose e produtos de papel e papelão
            '202217400': 0.002853,  # Artefatos diversos de papel, cartolina e papel-cartão
            '202219200': 0.401483,  # Produtos derivados do petróleo
            '202219300': 0.015666,  # Biocombustíveis
            '202219900': 0.057149,  # Derivados do petróleo e Biocombustíveis
            '202220100': 0.016433,  # Produtos químicos inorgânicos
            '202220200': 0.006169,  # Produtos químicos orgânicos
            '202220300': 0.012223,  # Resinas e elastômeros
            '202220400': 0.000784,  # Fibras e filamentos sintéticos
            '202220500': 0.007952,  # Defensivos agrícolas e desinfestantes domissanitários
            '202220600': 0.007895,  # Produtos de limpeza, cosméticos e artigos de perfumaria e de higiene pessoal
            '202220700': 0.002970,  # Tintas, vernizes, esmaltes, lacas e produtos afins
            '202220900': 0.004247,  # Produtos e preparados químicos diversos
            '202221200': 0.010910,  # Medicamentos
            '202222100': 0.005115,  # Artigos de borracha
            '202222200': 0.013499,  # Produtos de material plástico
            '202223100': 0.002286,  # Vidro e produtos de vidro
            '202223200': 0.002511,  # Cimento
            '202223300': 0.003461,  # Artefatos de concreto, cimento e fibrocimento
            '202223400': 0.002983,  # Produtos cerâmicos
            '202223900': 0.003093,  # Pedras, cal e outros produtos não-metálicos
            '202224100': 0.003914,  # Ferro-gusa e ferro-ligas
            '202224200': 0.023399,  # Produtos siderúrgicos
            '202224400': 0.015491,  # Produtos da metalurgia dos não-ferrosos
            '202225300': 0.001792,  # Forjados e estampados
            '202225900': 0.008380,  # Produtos diversos de metal
            '202226200': 0.014526,  # Eletroeletrônicos e Eletrodomésticos
            '202227100': 0.005862,  # Geradores, transformadores e motores elétricos
            '202227200': 0.000732,  # Pilhas, baterias e acumuladores
            '202227300': 0.005389,  # Equipamentos para distribuição e controle de energia elétrica
            '202227900': 0.000517,  # Equipamentos e aparelhos elétricos diversos
            '202228100': 0.003944,  # Motores, bombas, compressores e equipamentos de transmissão
            '202228200': 0.006218,  # Máquinas e equipamentos de uso geral
            '202228300': 0.009082,  # Máquinas e equipamentos para a agricultura
            '202228400': 0.001261,  # Máquinas-ferramenta
            '202228500': 0.004068,  # Máquinas e equipamentos de terraplenagem e pavimentação
            '202228600': 0.002423,  # Máquinas e equipamentos de uso específico
            '202229100': 0.021207,  # Automóveis, camionetas e utilitários
            '202229200': 0.007699,  # Caminhões e ônibus
            '202229300': 0.002463,  # Cabines, carrocerias e reboques
            '202229400': 0.016004,  # Peças e acessórios para veículos automotores
            '202230100': 0.001045,  # Embarcações
            '202230300': 0.000437,  # Veículos ferroviários
            '202230900': 0.004383,  # Outros equipamentos de transporte
            '202231100': 0.004405  # Moveis 
        }

    def load_data(self):
        """
        Carrega, mapeia e prepara dados de todas as empresas
        
        Returns:
            DataFrame: Dados consolidados com mapeamento setorial
        """
        try:
            # 1. Carregar dados do IPA
            df_ipa = self._load_ipa_data()
            
            # 2. Identificar empresas nos diretórios
            companies = self._scan_directory()
            print(f"\nEmpresas identificadas: {len(companies)}")

            # 3. Processamento de dados
            dfs = []
            for company in companies:
                try:
                    # Processar dados cadastrais
                    cadastro = self._load_cadastral_data(company['cadastro'])
                    if cadastro is None:
                        continue

                    # Processar dados financeiros
                    df_fin = self._load_financial_data(company['financeiro'])
                    if df_fin is None:
                        continue
                    
                    # Consolidar e mapear dados
                    df_empresa = self._consolidate_and_map_company_data(cadastro, df_fin, df_ipa)
                    
                    if df_empresa is not None:
                        dfs.append(df_empresa)
                        print(f"Empresa {company['nome']} processada com sucesso")
                    
                except Exception as e:
                    print(f"Erro ao processar {company['nome']}: {e}")
                    continue

            # 4. Consolidar dados de todas as empresas
            if not dfs:
                raise ValueError("Nenhum dado válido carregado")

            df_raw = pd.concat(dfs, ignore_index=True)
            
            # 5. Limpeza final dos dados
            df_raw = self._clean_data(df_raw)
            
            return df_raw

        except Exception as e:
            print(f"Erro no carregamento: {str(e)}")
            return None

    def _scan_directory(self):
        """
        Escaneia diretórios para encontrar empresas
        
        Returns:
            list: Lista de empresas com arquivos cadastrais e financeiros
        """
        companies = []
        
        cadastro_dir = self.base_dir / 'cadastro'
        financeiro_dir = self.base_dir / 'financeiro'
        
        for pdf_file in cadastro_dir.glob('*.pdf'):
            nome = pdf_file.stem
            xlsx_file = financeiro_dir / f"{nome}.xlsx"
            
            if xlsx_file.exists():
                companies.append({
                    'nome': nome,
                    'cadastro': pdf_file,
                    'financeiro': xlsx_file
                })
                
        return companies

    def _load_cadastral_data(self, pdf_file):
        """
        Carrega dados cadastrais do PDF
        
        Args:
            pdf_file (Path): Caminho do arquivo PDF
        
        Returns:
            dict: Dados cadastrais da empresa
        """
        try:
            doc = fitz.open(pdf_file)
            texto = " ".join(pagina.get_text() for pagina in doc)
            texto_limpo = ' '.join(texto.split())

            def extrair_codigo_empresa(texto_limpo):
                try:
                    inicio = texto_limpo.find('Código')
                    if inicio != -1:
                        inicio += len('Código')
                        fim = texto_limpo.find('Bolsa/Fonte', inicio)
                        if fim != -1:
                            codigo = texto_limpo[inicio:fim].strip().split()[0]
                            if len(codigo) >= 4:
                                return codigo
                except:
                    pass

                try:
                    nome_arquivo = str(pdf_file.stem)
                    codigo = nome_arquivo.split('_')[0].strip()
                    if len(codigo) >= 4:
                        return codigo
                except:
                    pass

                return None

            def extrair_cnpj(texto_limpo):
                import re
                matches = re.findall(r'CNPJ[^0-9]*([0-9]{14})', texto_limpo)
                if matches:
                    cnpj = matches[0]
                    return f"{cnpj[:2]}.{cnpj[2:5]}.{cnpj[5:8]}/{cnpj[8:12]}-{cnpj[12:]}"
                return None

            def extrair_naics(texto_limpo):
                try:
                    inicio = texto_limpo.lower().find('setor naics nível 3')
                    if inicio != -1:
                        inicio += len('setor naics nível 3')
                        fim = texto_limpo.lower().find('setor', inicio)
                        if fim != -1:
                            naics = texto_limpo[inicio:fim].strip()
                            return naics.lower()
                except:
                    pass
                return None

            def extrair_subsetor_bovespa(texto_limpo):
                try:
                    texto_lower = texto_limpo.lower()
                    for padrao in [
                        'subsetor bovespa', 
                        'segmento bovespa', 
                        'subsetor', 
                        'segmento'
                    ]:
                        pos = texto_lower.find(padrao)
                        if pos != -1:
                            subsetor = texto_lower[pos+len(padrao):].strip().split()[0]
                            return subsetor
                except:
                    pass
                return None

            # Extrair informações
            codigo_empresa = extrair_codigo_empresa(texto_limpo)
            if codigo_empresa is None:
                print(f"Erro: Não foi possível extrair o código da empresa do arquivo {pdf_file}")
                return None

            cnpj = extrair_cnpj(texto_limpo)
            setor_naics = extrair_naics(texto_limpo)
            subsetor_bovespa = extrair_subsetor_bovespa(texto_limpo)

            cadastro = {
                'empresa': codigo_empresa,
                'cnpj': cnpj,
                'setor_naics3': setor_naics or 'não classificado',
                'subsetor_bovespa': subsetor_bovespa or 'não classificado'
            }

            print(f"\nDados extraídos para {cadastro['empresa']}:")
            print(f"CNPJ: {cadastro['cnpj']}")
            print(f"Setor NAICS3: {cadastro['setor_naics3']}")
            print(f"Subsetor Bovespa: {cadastro['subsetor_bovespa']}")

            return cadastro

        except Exception as e:
            print(f"Erro ao processar arquivo PDF {pdf_file}: {str(e)}")
            return None

    def _load_financial_data(self, xlsx_file):
        """
        Carrega dados financeiros para o modelo de dois insumos (um variável e um fixo).

        No modelo de dois insumos:
        - Insumo Variável (variable_input) = COGS + Trabalho Indireto
        - Insumo Fixo (capital) = Imobilizado + Investimentos + Intangíveis

        O método:
        1. Identifica e extrai os componentes básicos (COGS e trabalho indireto)
        2. Calcula o insumo variável composto
        3. Obtém o Insumo Fixo (capital) a partir de seus componentes
        4. Organiza os dados em uma estrutura temporal consistente

        Args:
            xlsx_file (Path): Caminho do arquivo Excel

        Returns:
            DataFrame: Dados financeiros processados com a estrutura do modelo de dois insumos
        """
        try:
            # 1. Carregar arquivo Excel
            df = pd.read_excel(xlsx_file)

            # 2. Identificar coluna de descrição
            desc_cols = ['Consolidado', 'Descrição', 'Conta', 'Item', 'Demonstrativo']
            desc_col = next((col for col in desc_cols if col in df.columns), df.columns[0])

            # 3. Extrair componentes usando padrões da classe
            dados_base = {}

            # Processar cada componente necessário
            for var, padroes in self.padroes_contas['variaveis_base'].items():
                for padrao in padroes:
                    mask = df[desc_col].str.contains(padrao, na=False, case=False)
                    if mask.any():
                        idx = mask.idxmax()
                        dados_base[var] = pd.to_numeric(df.iloc[idx, 1:].values, errors='coerce')
                        print(f"Encontrado {var} com padrão: {padrao}")
                        break

            """
            # 4.1 Verificar componentes essenciais_variable_input
            componentes_essenciais_variable_input = ['cogs', 'trabalho_indireto']
            if not all(comp in dados_base for comp in componentes_essenciais_variable_input):
                missing = [comp for comp in componentes_essenciais_variable_input if comp not in dados_base]
                print(f"Aviso: Componentes essenciais de variable_input faltando: {', '.join(missing)}")
                return None

            # 4.2 Verificar componentes essenciais_capital
            componentes_essenciais_capital = ['imobilizado', 'investimentos', 'intangiveis']
            if not all(comp in dados_base for comp in componentes_essenciais_capital):
                missing = [comp for comp in componentes_essenciais_capital if comp not in dados_base]
                print(f"Aviso: Componentes essenciais de capital faltando: {', '.join(missing)}")
                return None            
            
           """ 
            
            # 4.1 Verificar componentes essenciais_variable_input
            componentes_essenciais_variable_input = ['cogs', 'trabalho_indireto']
            if not all(comp in dados_base for comp in componentes_essenciais_variable_input):
                missing = [comp for comp in componentes_essenciais_variable_input if comp not in dados_base]
                print(f"Aviso: Componentes essenciais de variable_input faltando: {', '.join(missing)}")
                return None

            # 4.2 Verificar componentes do capital
            componentes_capital = ['imobilizado']
            componentes_capital_disponiveis = [comp for comp in componentes_capital if comp in dados_base]

            if not componentes_capital_disponiveis:
                print(f"Aviso: Nenhum componente de capital encontrado entre: {', '.join(componentes_capital)}")
                return None

            # 5. Construir DataFrame com a estrutura do modelo de dois insumos
            datas = pd.to_datetime(df.columns[1:])

            # Calcular insumo variável composto (COGS + Trabalho Indireto)
            variable_input = dados_base['cogs'] + dados_base['trabalho_indireto']

            # Calcular capital ampliado (usando apenas componentes disponíveis)
            capital = pd.Series(0, index=datas)
            for comp in componentes_capital_disponiveis:
                capital += dados_base[comp]

            # Imprimir estatísticas sobre os componentes de capital
            print(f"Composição do capital:")
            for comp in componentes_capital_disponiveis:
                print(f"- {comp.capitalize()} médio: {dados_base[comp].mean():.2f}")
            print(f"- Capital total médio: {capital.mean():.2f}")

            # Criar DataFrame final com a estrutura do modelo
            dados_modelo = {
                'variable_input': variable_input,      # Insumo variável composto
                'capital': capital,                    # Capital (imobilizado)
                'receita': dados_base.get('receita'),  # Receita para cálculos de share
            }

            df_final = pd.DataFrame(dados_modelo, index=datas).T

            # 6. Validação final
            if df_final.empty:
                print("Aviso: DataFrame final está vazio")
                return None

            # Verificar validade dos dados
            n_valid = (~df_final.isnull()).sum().min()
            print(f"\nEstatísticas do carregamento:")
            print(f"Períodos: {len(df_final.columns)}")
            print(f"Observações válidas: {n_valid}")
            print(f"Composição do insumo variável:")
            print(f"- COGS médio: {dados_base['cogs'].mean():.2f}")
            print(f"- Trabalho indireto médio: {dados_base['trabalho_indireto'].mean():.2f}")
            print(f"- Insumo variável médio: {variable_input.mean():.2f}")

            return df_final

        except Exception as e:
            print(f"Erro no carregamento dos dados financeiros: {str(e)}")
            return None

    def _consolidate_and_map_company_data(self, cadastro, df_fin, df_ipa):
        """
        Consolida dados de uma empresa com mapeamento setorial completo
        
        Args:
            cadastro (dict): Dados cadastrais da empresa
            df_fin (DataFrame): Dados financeiros
            df_ipa (DataFrame): Dados do índice de preços
        
        Returns:
            DataFrame: Dados consolidados e mapeados
        """
        try:
            if cadastro is None or df_fin is None:
                return None

            registros = []
            for data in df_fin.columns:
                # Registro base
                registro = {
                    'empresa': cadastro['empresa'],
                    'cnpj': cadastro['cnpj'],
                    'setor_naics3': cadastro['setor_naics3'],
                    'subsetor_bovespa': cadastro['subsetor_bovespa'],
                    'data': data,
                    'ano': data.year,
                    'trimestre': (data.month - 1) // 3 + 1
                }

                # Adicionar variáveis financeiras
                for var in df_fin.index:
                    registro[var] = df_fin.loc[var, data]

                # Mapear setor para IPA
                registro_serie = pd.Series(registro)
                setor_ipa, fonte_mapeamento, peso_ipa = self._map_company_to_ipa(registro_serie)
                
                # Adicionar informações de mapeamento
                registro['setor_ipa'] = setor_ipa
                registro['fonte_mapeamento'] = fonte_mapeamento
                registro['peso_ipa'] = peso_ipa

                registros.append(registro)

            # Criar DataFrame
            df_empresa = pd.DataFrame(registros)

            return df_empresa

        except Exception as e:
            print(f"Erro na consolidação e mapeamento: {str(e)}")
            return None

    def _map_company_to_ipa(self, row):
        """
        Mapeia empresa para código IPA
        
        Args:
            row (Series): Linha de dados da empresa
        
        Returns:
            tuple: (código IPA, fonte de mapeamento, peso IPA)
        """
        empresa = row['empresa'].split()[0].upper()
        setor_naics = str(row.get('setor_naics3', '')).lower().strip()
        subsetor_bovespa = str(row.get('subsetor_bovespa', '')).lower().strip()

        # 1. Verificar exceções específicas
        if empresa in self.excecoes:
            codigo_ipa = self.excecoes[empresa]
            return codigo_ipa, 'exceção', self.pesos_ipa.get(codigo_ipa, 0)

        # 2. Mapear por NAICS
        for naics_key, codigo_ipa in self.naics_para_ipa.items():
            if naics_key in setor_naics:
                return codigo_ipa, 'naics', self.pesos_ipa.get(codigo_ipa, 0)

        # 3. Mapear por Bovespa
        for bovespa_key, codigo_ipa in self.bovespa_para_ipa.items():
            if bovespa_key in subsetor_bovespa:
                return codigo_ipa, 'bovespa', self.pesos_ipa.get(codigo_ipa, 0)

        # 4. Fallback padrão
        default_ipa = '202220200'  # Químicos orgânicos
        print(f"Aviso: Sem mapeamento para {empresa} (NAICS: {setor_naics}, Bovespa: {subsetor_bovespa})")
        return default_ipa, 'default', self.pesos_ipa.get(default_ipa, 0)

    def _load_ipa_data(self):
        """
        Carrega dados do índice IPA, tratando adequadamente números e datas em formato brasileiro.

        O método processa:
        - Números com separador de milhar como ponto (ex: '1.020,50')
        - Datas em múltiplos formatos brasileiros (ex: 'jan/22', 'jan-22', '01/22')

        Returns:
            DataFrame: Dados do IPA com índices e deflatores calculados
        """
        try:
            # Carrega o CSV com tratamento para números brasileiros
            df_ipa = pd.read_csv(
                self.ipa_path,
                sep=';',
                encoding='utf-8',
                decimal=',',
                thousands='.'
            )

            # Mapeamento de meses em português para inglês
            month_map = {
                'jan': 'Jan', 'fev': 'Feb', 'mar': 'Mar', 'abr': 'Apr',
                'mai': 'May', 'jun': 'Jun', 'jul': 'Jul', 'ago': 'Aug',
                'set': 'Sep', 'out': 'Oct', 'nov': 'Nov', 'dez': 'Dec'
            }

            # Normaliza meses e formato da data
            df_ipa['data'] = df_ipa['data'].str.lower()
            df_ipa['data'] = df_ipa['data'].replace(month_map, regex=True)

            def parse_date(date_str):
                """
                Tenta converter uma string de data usando múltiplos formatos.

                Args:
                    date_str: String contendo a data

                Returns:
                    datetime: Data convertida ou None se falhar
                """
                try:
                    # Tenta múltiplos formatos de data
                    for fmt in ['%b/%y', '%b-%y', '%m/%y', '%Y-%m']:
                        try:
                            return pd.to_datetime(date_str, format=fmt)
                        except ValueError:
                            continue

                    # Se nenhum formato funcionar, registra o problema
                    print(f"Formato de data não reconhecido: {date_str}")
                    return None

                except Exception as e:
                    print(f"Erro ao processar data {date_str}: {e}")
                    return None

            # Aplica o parsing de data com tratamento de erros
            df_ipa['data'] = df_ipa['data'].apply(parse_date)

            # Remove linhas com datas inválidas
            df_ipa = df_ipa.dropna(subset=['data'])

            # Define o índice e calcula o deflator
            df_ipa.set_index('data', inplace=True)
            base_value = df_ipa['indice'].iloc[-1]
            df_ipa['deflator'] = base_value / df_ipa['indice']

            return df_ipa

        except Exception as e:
            print(f"Erro no carregamento do IPA: {str(e)}")
            return None

    def _clean_data(self, df):
        """
        Cleans and standardizes raw financial data, focusing on basic data quality 
        without performing any markup-related calculations.

        This method handles:
        1. Basic data structure cleaning
        2. Variable type conversion and validation
        3. Treatment of missing and invalid values

        Markup-specific calculations (like input shares) are handled separately
        by the DLWMarkupEstimator class.

        Args:
            df (DataFrame): Raw financial data

        Returns:
            DataFrame: Cleaned and validated data
        """
        try:
            # 1. Basic Structure Cleaning
            df = df.drop_duplicates(subset=['empresa', 'data'])
            df = df.sort_values(['empresa', 'data'])

            # 2. Essential Variables - Required for later markup estimation
            essential_vars = {
                'receita': True,           # Revenue 
                'cogs': True,              # Cost of goods sold
                'trabalho_indireto': True, # Indirect labor costs
                'capital': True            # Fixed capital (renamed from imobilizado)
            }

            # 3. Supporting Variables
            supporting_vars = {
                'ativo_total': True,      # Balance sheet total
                'data': False,            # Time identifier
                'empresa': False,         # Firm identifier
                'setor_ipa': False,       # Sector identifier
                'peso_ipa': False         # Price index weight
            }

            # 4. Convert and Validate Variables
            for var, non_negative in {**essential_vars, **supporting_vars}.items():
                if var in df.columns:
                    # Skip non-numeric variables
                    if var in ['data', 'empresa', 'setor_ipa']:
                        continue

                    # Convert to numeric
                    df[var] = pd.to_numeric(df[var], errors='coerce')

                    # Apply non-negative constraint where applicable
                    if non_negative:
                        invalid_mask = df[var] <= 0
                        if invalid_mask.any():
                            print(f"Removing {invalid_mask.sum()} non-positive values from {var}")
                            df.loc[invalid_mask, var] = np.nan

            # 5. Remove observations missing essential variables
            essential_columns = list(essential_vars.keys())
            df = df.dropna(subset=essential_columns)

            # 6. Get variables using existing method
            df['variable_input'] = self._calculate_variable_input_costs(df)
            df['capital'] = self._calculate_capital_costs(df)

            # 7. Final Quality Check
            clean_obs = len(df)
            if clean_obs == 0:
                raise ValueError("No valid observations after cleaning")

            print(f"Final clean dataset contains {clean_obs} observations")

            return df

        except Exception as e:
            print(f"Error in data cleaning: {str(e)}")
            return df

    def aggregate_sectors(self, df_deflated):
        """
        Agrega setores após deflação

        Args:
            df_deflated (DataFrame): DataFrame com dados já deflacionados

        Returns:
            DataFrame: Dados com setores agregados
        """
        try:
            logging.info("Iniciando agregação setorial...")
            df_final = df_deflated.copy()
            sector_mapper = IPASectorMapper()

            # Adicionar classificação setorial agregada
            logging.info("Mapeando códigos setoriais...")
            df_final['setor_ipa_7d'] = df_final['setor_ipa'].apply(sector_mapper.get_7digit_sector)
            df_final['nome_setor'] = df_final['setor_ipa_7d'].apply(sector_mapper.get_sector_name)

            # Validar mapeamento
            unmapped = df_final[df_final['setor_ipa_7d'].isna()]
            if len(unmapped) > 0:
                logging.warning(f"{len(unmapped)} observações sem mapeamento setorial")
                logging.warning(f"Códigos não mapeados: {unmapped['setor_ipa'].unique()}")

            # Log de resultados da agregação
            n_original = df_final['setor_ipa'].nunique()
            n_aggregated = df_final['setor_ipa_7d'].nunique()
            logging.info(f"Setores originais: {n_original}")
            logging.info(f"Setores após agregação: {n_aggregated}")

            # Validar consistência do mapeamento
            mapping_check = df_final.groupby(['setor_ipa', 'setor_ipa_7d', 'nome_setor']).size().reset_index()
            logging.info("\nMapeamento de setores:")
            for _, row in mapping_check.iterrows():
                logging.info(f"{row['setor_ipa']} -> {row['setor_ipa_7d']} ({row['nome_setor']})")

            return df_final

        except Exception as e:
            logging.error(f"Erro na agregação setorial: {str(e)}")
            traceback.print_exc()
            return df_deflated

        
class IPADeflator:
    def apply_weighted_deflator(self, df, df_ipa):
        """
        Applies weighted deflation to monetary variables.
        """
        try:
            # Get base period index value
            indice_base = df_ipa['indice'].iloc[-1]

            # Filter data to periods with available price indices
            data_minima_ipa = df_ipa.index.min()
            df_deflated = df[df['data'] >= data_minima_ipa].copy()

            # Convert index to period for proper matching
            df_ipa.index = df_ipa.index.to_period('M')

            # Variables to deflate
            monetary_vars = ['variable_input', 'capital', 'imobilizado', 'receita', 'cogs', 'trabalho_indireto']

            # Apply deflation to each variable
            for var in monetary_vars:
                if var not in df_deflated.columns:
                    logging.warning(f"Variable {var} not found in dataset")
                    continue

                # Store nominal values
                df_deflated[f'{var}_nominal'] = df_deflated[var]

                # Apply deflation only to non-null values
                for idx, row in df_deflated.iterrows():
                    if pd.isnull(row[var]):
                        continue

                    periodo = row['data'].to_period('M')
                    if periodo in df_ipa.index:
                        indice_periodo = df_ipa.loc[periodo, 'indice']
                        deflator = (indice_base / indice_periodo) ** row['peso_ipa']

                        # Safe multiplication with null check
                        current_value = df_deflated.loc[idx, var]
                        if pd.notnull(current_value):
                            df_deflated.loc[idx, var] = current_value * deflator

            # Validate results
            for var in monetary_vars:
                if var in df_deflated.columns:
                    null_count = df_deflated[var].isnull().sum()
                    if null_count > 0:
                        logging.warning(f"{null_count} null values in deflated {var}")

            return df_deflated

        except Exception as e:
            logging.error(f"Error in deflation process: {str(e)}")
            raise

def print_sector_summary(df, sector_mapper):
    """
    Imprime uma tabela síntese com estatísticas descritivas por setor.

    Args:
        df (pd.DataFrame): DataFrame com os dados finais processados.
        sector_mapper (IPASectorMapper): Instância da classe IPASectorMapper para mapeamento de setores.
    """
    # Verificar se a coluna de setor agregado existe
    if 'setor_ipa_7d' not in df.columns:
        logging.error("Coluna 'setor_ipa_7d' não encontrada no DataFrame.")
        return

    # Obter contagens, médias e desvios padrão por setor
    sector_summary = df.groupby('setor_ipa_7d').agg(
        empresas=('empresa', 'nunique'),
        observacoes=('empresa', 'count'),
        receita_media=('receita', 'mean'),
        receita_desvio=('receita', 'std'),
        input_var_medio=('variable_input', 'mean'),
        input_var_desvio=('variable_input', 'std'),
        capital_medio=('capital', 'mean'),
        capital_desvio=('capital', 'std')
    ).reset_index()

    # Renomear coluna de setor para o nome
    sector_summary['setor'] = sector_summary['setor_ipa_7d'].map(lambda x: sector_mapper.get_sector_name(x))

    # Reordenar colunas
    sector_summary = sector_summary[['setor', 'empresas', 'observacoes', 
                                     'receita_media', 'receita_desvio',
                                     'input_var_medio', 'input_var_desvio',
                                     'capital_medio', 'capital_desvio']]

    # Formatar valores numéricos
    numeric_cols = ['receita_media', 'receita_desvio',
                    'input_var_medio', 'input_var_desvio',
                    'capital_medio', 'capital_desvio']
    sector_summary[numeric_cols] = sector_summary[numeric_cols].applymap(lambda x: f"{x:,.2f}")

    # Imprimir tabela
    print("\nResumo por Setor:")
    print(sector_summary.to_string(index=False))

if __name__ == '__main__':
    try:
        # Configure directories and logging
        base_dir = Path(r'C:\Users\fabio\OneDrive\Projeto_Markup\Data\raw')
        ipa_path = Path(r'C:\Users\fabio\OneDrive\Projeto_Markup\Data\Index\ipa_data.csv')
        output_dir = Path(r'C:\Users\fabio\OneDrive\Projeto_Markup\Results\Model3\v1')
        
        # Create output directory if it doesn't exist
        output_dir.mkdir(parents=True, exist_ok=True)
        
        # Set up logging configuration
        log_path = output_dir / 'estimation_log.txt'
        logging.basicConfig(
            level=logging.INFO,
            format='%(asctime)s - %(levelname)s - %(message)s',
            handlers=[
                logging.FileHandler(log_path),
                logging.StreamHandler()
            ]
        )
        
        logging.info("Starting two-input markup estimation process")
        
        # Validate input files
        if not base_dir.exists():
            raise FileNotFoundError(f"Base directory not found: {base_dir}")
        if not ipa_path.exists():
            raise FileNotFoundError(f"IPA file not found: {ipa_path}")
            
        # Initialize our main classes
        data_loader = DataLoader(base_dir, ipa_path)
        deflator = IPADeflator()
        
        # Step 1: Load and clean raw data
        logging.info("Loading and cleaning raw data...")
        df_raw = data_loader.load_data()
        
        if df_raw is None or df_raw.empty:
            raise ValueError("Failed to load valid data")
            
        if df_raw is not None:
            # Check data quality before proceeding
            null_counts = df_raw.isnull().sum()
            logging.info("\nMissing value summary:")
            for col, count in null_counts.items():
                if count > 0:
                    logging.info(f"{col}: {count} missing values ({count/len(df_raw)*100:.1f}%)")

            # Validate variable input calculation
            if 'variable_input' in df_raw.columns:
                invalid_inputs = df_raw['variable_input'].isnull().sum()
                logging.info(f"\nVariable input calculation:")
                logging.info(f"Invalid/missing values: {invalid_inputs}")
        
        
        # Log initial data statistics
        logging.info("Raw data loaded:")
        logging.info(f"Total observations: {len(df_raw)}")
        logging.info(f"Unique firms: {df_raw['empresa'].nunique()}")
        logging.info(f"Time period: {df_raw['data'].min():%Y-%m} to {df_raw['data'].max():%Y-%m}")
        
        # Step 2: Load price indices and apply deflation
        logging.info("Loading price indices and applying deflation...")
        df_ipa = data_loader._load_ipa_data()
        df_deflated = deflator.apply_weighted_deflator(df_raw, df_ipa)
        
        # Step 3: Aggregate sectors
        logging.info("Performing sector aggregation...")
        df_final = data_loader.aggregate_sectors(df_deflated)
        
        # Validação da agregação - ADICIONAR ESTA VERIFICAÇÃO
        if 'setor_ipa_7d' not in df_final.columns:
            raise ValueError("Sector aggregation failed: setor_ipa_7d column not created")
        
        # Save processed datasets
        logging.info("Saving processed datasets...")
        logging.info("\nSetor aggregation results:")
        logging.info(f"Original sectors (setor_ipa): {df_final['setor_ipa'].nunique()}")
        logging.info(f"Aggregated sectors (setor_ipa_7d): {df_final['setor_ipa_7d'].nunique()}")
        
        # Save with clear naming convention
        df_raw.to_excel(output_dir / 'raw_data.xlsx', index=False)
        df_deflated.to_excel(output_dir / 'deflated_data.xlsx', index=False)
        df_final.to_excel(output_dir / 'final_data.xlsx', index=False)
        
        # Criar instância do IPASectorMapper
        sector_mapper = IPASectorMapper()
        
        # Imprimir resumo por setor
        print_sector_summary(df_final, sector_mapper)
        
        # Log final summary statistics
        logging.info("\nFinal Dataset Summary:")
        logging.info(f"Total observations: {len(df_final)}")
        logging.info(f"Unique firms: {df_final['empresa'].nunique()}")
        logging.info(f"Original IPA sectors: {df_final['setor_ipa'].nunique()}")
        logging.info(f"Aggregated sectors: {df_final['setor_ipa_7d'].nunique()}")
        
        # Calculate and log data quality metrics
        missing_rates = df_final.isnull().mean() * 100
        logging.info("\nData Quality Metrics:")
        for col, rate in missing_rates.items():
            if rate > 0:
                logging.info(f"Missing rate for {col}: {rate:.1f}%")
                
        logging.info("Processing completed successfully!")
        print(f"\nResults saved in: {output_dir}")
        
    except Exception as e:
        logging.error(f"Fatal error in processing: {str(e)}")
        traceback.print_exc()
        raise
# Out:
# 2025-03-05 16:35:11,219 - INFO - Starting two-input markup estimation process
# 2025-03-05 16:35:11,226 - INFO - Loading and cleaning raw data...
# Empresas identificadas: 127
#
# Dados extraídos para ABEV:
# CNPJ: None
# Setor NAICS3: indústria de bebidas
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 4328758.57
# - Capital total médio: 4328758.57
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 3529056.91
# - Trabalho indireto médio: 492973.64
# - Insumo variável médio: 4022030.55
# Empresa ABEV processada com sucesso
#
# Dados extraídos para AGRO:
# CNPJ: 07.628.528/0001-59
# Setor NAICS3: -
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 93755.38
# - Capital total médio: 93755.38
#
# Estatísticas do carregamento:
# Períodos: 75
# Observações válidas: 1
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa AGRO processada com sucesso
#
# Dados extraídos para AGXY:
# CNPJ: 21.240.146/0001-84
# Setor NAICS3: atividades auxiliares à agricultura
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 420.55
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 0.00
# - Trabalho indireto médio: 15405.18
# - Insumo variável médio: 15405.18
# Empresa AGXY processada com sucesso
#
# Dados extraídos para ALPA:
# CNPJ: 61.079.117/0001-05
# Setor NAICS3: indústria de calçados
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 326405.66
# - Capital total médio: 326405.66
#
# Estatísticas do carregamento:
# Períodos: 151
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 470841.54
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa ALPA processada com sucesso
#
# Dados extraídos para APTI:
# CNPJ: 61.156.931/0001-78
# Setor NAICS3: indústria de molas e produtos de arame
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 51644.43
# - Capital total médio: 51644.43
#
# Estatísticas do carregamento:
# Períodos: 106
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 4723.42
# - Trabalho indireto médio: 9799.74
# - Insumo variável médio: 14523.15
# Empresa APTI processada com sucesso
#
# Dados extraídos para AURA:
# CNPJ: 07.857.093/0001-14
# Setor NAICS3: mineração de metais
# Subsetor Bovespa: mineração
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1669452.39
# - Capital total médio: 1669452.39
#
# Estatísticas do carregamento:
# Períodos: 23
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 758909.17
# - Trabalho indireto médio: 66930.74
# - Insumo variável médio: 825839.91
# Empresa AURA processada com sucesso
#
# Dados extraídos para BALM:
# CNPJ: 61.374.161/0001-30
# Setor NAICS3: indústria de equipamentos e materiais para uso médico
# Subsetor Bovespa: equipamentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 12875.95
# - Capital total médio: 12875.95
#
# Estatísticas do carregamento:
# Períodos: 106
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 21565.72
# - Trabalho indireto médio: 9615.21
# - Insumo variável médio: 31180.92
# Empresa BALM processada com sucesso
#
# Dados extraídos para BAUH:
# CNPJ: 95.426.862/0001-97
# Setor NAICS3: outras indústrias de alimentos
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 23984.70
# - Capital total médio: 23984.70
#
# Estatísticas do carregamento:
# Períodos: 105
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 43447.27
# - Trabalho indireto médio: 2033.04
# - Insumo variável médio: 45480.30
# Empresa BAUH processada com sucesso
#
# Dados extraídos para BDLL:
# CNPJ: 60.851.615/0001-53
# Setor NAICS3: industria de máquinas agrícolas, de construção e mineração
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 75211.73
# - Capital total médio: 75211.73
#
# Estatísticas do carregamento:
# Períodos: 151
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 91750.32
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa BDLL processada com sucesso
#
# Dados extraídos para BEEF:
# CNPJ: 67.620.377/0001-14
# Setor NAICS3: abatedouros
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1305703.64
# - Capital total médio: 1305703.64
#
# Estatísticas do carregamento:
# Períodos: 74
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 3142000.80
# - Trabalho indireto médio: 156866.03
# - Insumo variável médio: 3298866.82
# Empresa BEEF processada com sucesso
#
# Dados extraídos para BIOM:
# CNPJ: 04.752.991/0001-10
# Setor NAICS3: pesquisa científica
# Subsetor Bovespa: medicamentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 63457.00
# - Capital total médio: 63457.00
#
# Estatísticas do carregamento:
# Períodos: 91
# Observações válidas: 1
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa BIOM processada com sucesso
#
# Dados extraídos para BRAV:
# CNPJ: 12.091.809/0001-55
# Setor NAICS3: extração de petróleo e gás
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 9897.68
# - Capital total médio: 9897.68
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 0.00
# - Trabalho indireto médio: 59958.50
# - Insumo variável médio: 59958.50
# Empresa BRAV processada com sucesso
#
# Dados extraídos para BRFS:
# CNPJ: None
# Setor NAICS3: abatedouros
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 3819259.13
# - Capital total médio: 3819259.13
#
# Estatísticas do carregamento:
# Períodos: 150
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 5677938.59
# - Trabalho indireto médio: 85038.56
# - Insumo variável médio: 5762977.16
# Empresa BRFS processada com sucesso
#
# Dados extraídos para BRIT:
# CNPJ: 19.796.586/0001-70
# Setor NAICS3: administração de empresas e empreendimentos
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 0.00
# - Capital total médio: 0.00
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 1
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: 1300.61
# - Insumo variável médio: nan
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para BRKM:
# CNPJ: 42.150.391/0001-70
# Setor NAICS3: -
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 7568125.94
# - Capital total médio: 7568125.94
#
# Estatísticas do carregamento:
# Períodos: 151
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 9002772.49
# - Trabalho indireto médio: 335184.37
# - Insumo variável médio: 9337956.86
# Empresa BRKM processada com sucesso
#
# Dados extraídos para BRQB:
# CNPJ: 36.542.025/0001-64
# Setor NAICS3: editoras de software
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 10669.62
# - Capital total médio: 10669.62
#
# Estatísticas do carregamento:
# Períodos: 40
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 199196.55
# - Trabalho indireto médio: 50500.72
# - Insumo variável médio: 249697.27
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para CAMB:
# CNPJ: 61.088.894/0001-08
# Setor NAICS3: indústria de calçados
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 31821.73
# - Capital total médio: 31821.73
#
# Estatísticas do carregamento:
# Períodos: 124
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 66720.49
# - Trabalho indireto médio: 9018.46
# - Insumo variável médio: 75738.96
# Empresa CAMB processada com sucesso
#
# Dados extraídos para CAML:
# CNPJ: 64.904.295/0001-03
# Setor NAICS3: outras indústrias de alimentos
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 879923.47
# - Capital total médio: 879923.47
#
# Estatísticas do carregamento:
# Períodos: 34
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 2753708.88
# - Trabalho indireto médio: 183529.56
# - Insumo variável médio: 2937238.44
# Empresa CAML processada com sucesso
#
# Dados extraídos para CASH:
# CNPJ: 14.110.585/0001-07
# Setor NAICS3: outros serviços de informação
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 3603.32
# - Capital total médio: 3603.32
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 145057.23
# - Trabalho indireto médio: 0.00
# - Insumo variável médio: 145057.23
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para CATA:
# CNPJ: 19.526.748/0001-50
# Setor NAICS3: tecelagens
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 81182.07
# - Capital total médio: 81182.07
#
# Estatísticas do carregamento:
# Períodos: 105
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 79517.78
# - Trabalho indireto médio: 7359.88
# - Insumo variável médio: 86877.66
# Empresa CATA processada com sucesso
#
# Dados extraídos para CBAV:
# CNPJ: 61.409.892/0001-73
# Setor NAICS3: mineração de metais
# Subsetor Bovespa: mineração
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 4646303.82
# - Capital total médio: 4646303.82
#
# Estatísticas do carregamento:
# Períodos: 17
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 3717655.18
# - Trabalho indireto médio: 197690.12
# - Insumo variável médio: 3915345.29
# Empresa CBAV processada com sucesso
#
# Dados extraídos para CEDO:
# CNPJ: 17.245.234/0001-00
# Setor NAICS3: tecelagens
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 120339.59
# - Capital total médio: 120339.59
#
# Estatísticas do carregamento:
# Períodos: 113
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 169133.06
# - Trabalho indireto médio: 11150.40
# - Insumo variável médio: 180283.46
# Empresa CEDO processada com sucesso
#
# Dados extraídos para CMIN:
# CNPJ: 08.902.291/0001-15
# Setor NAICS3: mineração de metais
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 7717615.59
# - Capital total médio: 7717615.59
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 4418885.18
# - Trabalho indireto médio: 86343.05
# - Insumo variável médio: 4505228.23
# Empresa CMIN processada com sucesso
#
# Dados extraídos para CRPG:
# CNPJ: 15.115.504/0001-24
# Setor NAICS3: -
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 163025.99
# - Capital total médio: 163025.99
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 151150.28
# - Trabalho indireto médio: 10813.30
# - Insumo variável médio: 161963.58
# Empresa CRPG processada com sucesso
#
# Dados extraídos para CSNA:
# CNPJ: 33.042.730/0001-04
# Setor NAICS3: transformação de aço em produtos de aço
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 7739157.44
# - Capital total médio: 7739157.44
#
# Estatísticas do carregamento:
# Períodos: 141
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 3703616.45
# - Trabalho indireto médio: 133301.10
# - Insumo variável médio: 3836917.55
# Empresa CSNA processada com sucesso
#
# Dados extraídos para CTCA:
# CNPJ: 06.981.381/0001-13
# Setor NAICS3: -
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 117397.03
# - Capital total médio: 117397.03
#
# Estatísticas do carregamento:
# Períodos: 37
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 61630.51
# - Trabalho indireto médio: 44217.27
# - Insumo variável médio: 105847.78
# Empresa CTCA processada com sucesso
#
# Dados extraídos para CTKA:
# CNPJ: 82.640.558/0001-04
# Setor NAICS3: indústria de roupas de tecido
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 77751.83
# - Capital total médio: 77751.83
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 88341.05
# - Trabalho indireto médio: 11958.49
# - Insumo variável médio: 100299.54
# Empresa CTKA processada com sucesso
#
# Dados extraídos para CTNM:
# CNPJ: 22.677.520/0001-76
# Setor NAICS3: indústria de roupas de tecido
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 202637.53
# - Capital total médio: 202637.53
#
# Estatísticas do carregamento:
# Períodos: 128
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 84802.76
# - Trabalho indireto médio: 38063.62
# - Insumo variável médio: 122866.38
# Empresa CTNM processada com sucesso
#
# Dados extraídos para CTSA:
# CNPJ: 21.255.567/0001-89
# Setor NAICS3: tecelagens
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 111169.98
# - Capital total médio: 111169.98
#
# Estatísticas do carregamento:
# Períodos: 103
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 150573.82
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa CTSA processada com sucesso
#
# Dados extraídos para DESK:
# CNPJ: 08.170.849/0001-15
# Setor NAICS3: operadoras de telecomunicações a cabo
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 718667.62
# - Capital total médio: 718667.62
#
# Estatísticas do carregamento:
# Períodos: 16
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 99371.19
# - Trabalho indireto médio: 28900.00
# - Insumo variável médio: 128271.19
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para DOHL:
# CNPJ: 84.683.408/0001-03
# Setor NAICS3: indústria de roupas de tecido
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 140383.36
# - Capital total médio: 140383.36
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 121954.02
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa DOHL processada com sucesso
#
# Dados extraídos para DXCO:
# CNPJ: 97.837.181/0001-47
# Setor NAICS3: -
# Subsetor Bovespa: madeira
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 2048119.77
# - Capital total médio: 2048119.77
#
# Estatísticas do carregamento:
# Períodos: 74
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 1495117.73
# - Trabalho indireto médio: 78580.32
# - Insumo variável médio: 1573698.05
# Empresa DXCO processada com sucesso
#
# Dados extraídos para EALT:
# CNPJ: 82.643.537/0001-34
# Setor NAICS3: transformação de aço em produtos de aço
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 104211.27
# - Capital total médio: 104211.27
#
# Estatísticas do carregamento:
# Períodos: 113
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 80340.73
# - Trabalho indireto médio: 9435.55
# - Insumo variável médio: 89776.27
# Empresa EALT processada com sucesso
#
# Dados extraídos para EMBR:
# CNPJ: 07.689.002/0001-89
# Setor NAICS3: indústria de equipamentos aeroespacias
# Subsetor Bovespa: material
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1385136.72
# - Capital total médio: 1385136.72
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 3097753.40
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa EMBR processada com sucesso
#
# Dados extraídos para ENJU:
# CNPJ: 16.922.038/0001-51
# Setor NAICS3: vendas por correio ou meio eletrônico
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 6920.00
# - Capital total médio: 6920.00
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 42167.59
# - Trabalho indireto médio: 46355.27
# - Insumo variável médio: 88522.86
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para ETER:
# CNPJ: 61.092.037/0001-81
# Setor NAICS3: indústria de outros produtos de minerais não metálicos
# Subsetor Bovespa: construção
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 63971.40
# - Capital total médio: 63971.40
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 119653.05
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa ETER processada com sucesso
#
# Dados extraídos para EUCA:
# CNPJ: 56.643.018/0001-66
# Setor NAICS3: indústria de produtos de madeira compensada e afins
# Subsetor Bovespa: madeira
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 214731.16
# - Capital total médio: 214731.16
#
# Estatísticas do carregamento:
# Períodos: 149
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 112466.87
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa EUCA processada com sucesso
#
# Dados extraídos para FESA:
# CNPJ: 15.141.799/0001-03
# Setor NAICS3: fundição
# Subsetor Bovespa: siderurgia
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 308940.29
# - Capital total médio: 308940.29
#
# Estatísticas do carregamento:
# Períodos: 150
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 278576.82
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa FESA processada com sucesso
#
# Dados extraídos para FHER:
# CNPJ: 22.266.175/0001-88
# Setor NAICS3: indústria de fertilizantes e pesticidas
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 446247.04
# - Capital total médio: 446247.04
#
# Estatísticas do carregamento:
# Períodos: 72
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 2184531.03
# - Trabalho indireto médio: 54021.51
# - Insumo variável médio: 2238552.54
# Empresa FHER processada com sucesso
#
# Dados extraídos para FIQE:
# CNPJ: 02.255.187/0001-08
# Setor NAICS3: operadoras de telecomunicações a cabo
# Subsetor Bovespa: telecomunicações
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 430877.81
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 177150.22
# - Trabalho indireto médio: 46207.06
# - Insumo variável médio: 223357.28
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para FRAS:
# CNPJ: 88.610.126/0001-29
# Setor NAICS3: indústria de autopeças
# Subsetor Bovespa: material
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 151480.79
# - Capital total médio: 151480.79
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 181105.16
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa FRAS processada com sucesso
#
# Dados extraídos para FRIO:
# CNPJ: 04.821.041/0001-08
# Setor NAICS3: indústria de equipamentos de refrigeração
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 75915.28
# - Capital total médio: 75915.28
#
# Estatísticas do carregamento:
# Períodos: 72
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 264646.56
# - Trabalho indireto médio: 15667.14
# - Insumo variável médio: 280313.69
# Empresa FRIO processada com sucesso
#
# Dados extraídos para GGBR:
# CNPJ: 33.611.500/0001-19
# Setor NAICS3: transformação de aço em produtos de aço
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 792699.80
# - Capital total médio: 792699.80
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 865787.90
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa GGBR processada com sucesso
#
# Dados extraídos para GOAU:
# CNPJ: 92.690.783/0001-09
# Setor NAICS3: transformação de aço em produtos de aço
# Subsetor Bovespa: siderurgia
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 2084.93
# - Capital total médio: 2084.93
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 91.61
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa GOAU processada com sucesso
#
# Dados extraídos para GRAO:
# CNPJ: 18.483.666/0001-03
# Setor NAICS3: -
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1449.72
# - Capital total médio: 1449.72
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 1092439.72
# - Trabalho indireto médio: 18345.89
# - Insumo variável médio: 1110785.61
# Empresa GRAO processada com sucesso
#
# Dados extraídos para GRND:
# CNPJ: None
# Setor NAICS3: não classificado
# Subsetor Bovespa: listagem
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 295604.40
# - Capital total médio: 295604.40
#
# Estatísticas do carregamento:
# Períodos: 84
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 588674.98
# - Trabalho indireto médio: 43199.43
# - Insumo variável médio: 631874.40
# Empresa GRND processada com sucesso
#
# Dados extraídos para HAGA:
# CNPJ: 30.540.991/0001-66
# Setor NAICS3: indústria de ferragens
# Subsetor Bovespa: construção
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 8648.69
# - Capital total médio: 8648.69
#
# Estatísticas do carregamento:
# Períodos: 106
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 10036.89
# - Trabalho indireto médio: 2094.37
# - Insumo variável médio: 12131.26
# Empresa HAGA processada com sucesso
#
# Dados extraídos para IFCM:
# CNPJ: 38.456.921/0001-36
# Setor NAICS3: -
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 0.00
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 0
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para INEP:
# CNPJ: 76.627.504/0001-06
# Setor NAICS3: outras outras indústrias
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 83532.83
# - Capital total médio: 83532.83
#
# Estatísticas do carregamento:
# Períodos: 151
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 29626.18
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa INEP processada com sucesso
#
# Dados extraídos para INTB:
# CNPJ: 82.901.000/0001-27
# Setor NAICS3: indústria de equipamentos de comunicação
# Subsetor Bovespa: computadores
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 380272.18
# - Capital total médio: 380272.18
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 1294269.50
# - Trabalho indireto médio: 96294.05
# - Insumo variável médio: 1390563.55
# Empresa INTB processada com sucesso
#
# Dados extraídos para JALL:
# CNPJ: 02.635.522/0001-95
# Setor NAICS3: outras outras indústrias
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1901142.29
# - Capital total médio: 1901142.29
#
# Estatísticas do carregamento:
# Períodos: 21
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 485902.57
# - Trabalho indireto médio: 55258.76
# - Insumo variável médio: 541161.33
# Empresa JALL processada com sucesso
#
# Dados extraídos para JBSS:
# CNPJ: 02.916.265/0001-60
# Setor NAICS3: abatedouros
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 8953590.89
# - Capital total médio: 8953590.89
#
# Estatísticas do carregamento:
# Períodos: 74
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 12810494.84
# - Trabalho indireto médio: 1064157.30
# - Insumo variável médio: 13874652.14
# Empresa JBSS processada com sucesso
#
# Dados extraídos para JOPA:
# CNPJ: 87.456.562/0001-22
# Setor NAICS3: moinho de grãos
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 158957.45
# - Capital total médio: 158957.45
#
# Estatísticas do carregamento:
# Períodos: 106
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 407242.77
# - Trabalho indireto médio: 34502.41
# - Insumo variável médio: 441745.18
# Empresa JOPA processada com sucesso
#
# Dados extraídos para KEPL:
# CNPJ: 91.983.056/0001-69
# Setor NAICS3: indústria de estruturas metálicas
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 5595.35
#
# Estatísticas do carregamento:
# Períodos: 152
# Observações válidas: 0
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa KEPL processada com sucesso
#
# Dados extraídos para KLBN:
# CNPJ: 89.637.490/0001-45
# Setor NAICS3: indústria de papel, celulose e papelão
# Subsetor Bovespa: madeira
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 5562139.20
# - Capital total médio: 5562139.20
#
# Estatísticas do carregamento:
# Períodos: 150
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 1689178.21
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa KLBN processada com sucesso
#
# Dados extraídos para LAND:
# CNPJ: 40.337.136/0001-06
# Setor NAICS3: outras outras indústrias
# Subsetor Bovespa: agropecuária
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 175815.11
# - Capital total médio: 175815.11
#
# Estatísticas do carregamento:
# Períodos: 74
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 264899.19
# - Trabalho indireto médio: 24791.45
# - Insumo variável médio: 289690.64
# Empresa LAND processada com sucesso
#
# Dados extraídos para LMED:
# CNPJ: 02.357.251/0001-53
# Setor NAICS3: indústria de equipamentos e materiais para uso médico
# Subsetor Bovespa: equipamentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 84513.73
# - Capital total médio: 84513.73
#
# Estatísticas do carregamento:
# Períodos: 26
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 61545.12
# - Trabalho indireto médio: 13981.58
# - Insumo variável médio: 75526.69
# Empresa LMED processada com sucesso
#
# Dados extraídos para LUPA:
# CNPJ: 89.463.822/0001-12
# Setor NAICS3: forjarias e estamparias
# Subsetor Bovespa: petróleo
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 73629.64
# - Capital total médio: 73629.64
#
# Estatísticas do carregamento:
# Períodos: 78
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 50031.36
# - Trabalho indireto médio: 10391.73
# - Insumo variável médio: 60423.09
# Empresa LUPA processada com sucesso
#
# Dados extraídos para LVTC:
# CNPJ: 05.917.486/0001-40
# Setor NAICS3: comércio eletrônico e corretores
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 411092.94
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 414159.28
# - Trabalho indireto médio: 11040.22
# - Insumo variável médio: 425199.50
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para LWSA:
# CNPJ: 02.351.877/0001-52
# Setor NAICS3: editoras de software
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 96906.15
# - Capital total médio: 96906.15
#
# Estatísticas do carregamento:
# Períodos: 26
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 126262.00
# - Trabalho indireto médio: 23790.50
# - Insumo variável médio: 150052.50
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para MDIA:
# CNPJ: 07.206.816/0001-15
# Setor NAICS3: outras indústrias de alimentos
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1840099.77
# - Capital total médio: 1840099.77
#
# Estatísticas do carregamento:
# Períodos: 78
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 1785369.19
# - Trabalho indireto médio: 122178.86
# - Insumo variável médio: 1907548.05
# Empresa MDIA processada com sucesso
#
# Dados extraídos para MGEL:
# CNPJ: 61.065.298/0001-02
# Setor NAICS3: forjarias e estamparias
# Subsetor Bovespa: siderurgia
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 55776.64
#
# Estatísticas do carregamento:
# Períodos: 147
# Observações válidas: 0
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa MGEL processada com sucesso
#
# Dados extraídos para MLAS:
# CNPJ: 59.717.553/0001-02
# Setor NAICS3: indústria de computadores e periféricos
# Subsetor Bovespa: computadores
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 199295.56
#
# Estatísticas do carregamento:
# Períodos: 18
# Observações válidas: 1
# Composição do insumo variável:
# - COGS médio: 1999426.50
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa MLAS processada com sucesso
#
# Dados extraídos para MNDL:
# CNPJ: 88.610.191/0001-54
# Setor NAICS3: indústria de ferragens
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 111421.70
# - Capital total médio: 111421.70
#
# Estatísticas do carregamento:
# Períodos: 149
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 95077.15
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa MNDL processada com sucesso
#
# Dados extraídos para MNPR:
# CNPJ: 90.076.886/0001-40
# Setor NAICS3: abatedouros
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 18.73
# - Capital total médio: 18.73
#
# Estatísticas do carregamento:
# Períodos: 138
# Observações válidas: 1
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: 490.23
# - Insumo variável médio: nan
# Empresa MNPR processada com sucesso
#
# Dados extraídos para MRFG:
# CNPJ: 03.853.896/0001-40
# Setor NAICS3: abatedouros
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 2083219.81
# - Capital total médio: 2083219.81
#
# Estatísticas do carregamento:
# Períodos: 74
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 3611504.78
# - Trabalho indireto médio: 85840.31
# - Insumo variável médio: 3697345.09
# Empresa MRFG processada com sucesso
#
# Dados extraídos para MSPA:
# CNPJ: 60.730.348/0001-66
# Setor NAICS3: indústria de produtos de papel e papelão
# Subsetor Bovespa: madeira
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 737127.87
# - Capital total médio: 737127.87
#
# Estatísticas do carregamento:
# Períodos: 105
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 1621.79
# - Trabalho indireto médio: 14318.32
# - Insumo variável médio: 15940.11
# Empresa MSPA processada com sucesso
#
# Dados extraídos para MTSA:
# CNPJ: 86.375.425/0001-09
# Setor NAICS3: outras indústrias de produtos de metal
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 38862.12
# - Capital total médio: 38862.12
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 79776.34
# - Trabalho indireto médio: 6846.89
# - Insumo variável médio: 86623.23
# Empresa MTSA processada com sucesso
#
# Dados extraídos para MWET:
# CNPJ: 84.683.671/0001-94
# Setor NAICS3: indústria de autopeças
# Subsetor Bovespa: material
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 45952.74
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 61511.48
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa MWET processada com sucesso
#
# Dados extraídos para NEMO:
# CNPJ: 60.651.809/0001-05
# Setor NAICS3: administração de empresas e empreendimentos
# Subsetor Bovespa: madeira
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 1299.73
# - Capital total médio: 1299.73
#
# Estatísticas do carregamento:
# Períodos: 105
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 0.00
# - Trabalho indireto médio: 12254.07
# - Insumo variável médio: 12254.07
# Empresa NEMO processada com sucesso
#
# Dados extraídos para NGRD:
# CNPJ: 10.139.870/0001-08
# Setor NAICS3: editoras de software
# Subsetor Bovespa: programas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 0.00
# - Capital total médio: 0.00
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 0.00
# - Trabalho indireto médio: 2480.86
# - Insumo variável médio: 2480.86
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para NORD:
# CNPJ: 60.884.319/0001-59
# Setor NAICS3: indústria de outros tipos de máquinas
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 9815.30
# - Capital total médio: 9815.30
#
# Estatísticas do carregamento:
# Períodos: 149
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 5291.40
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa NORD processada com sucesso
#
# Dados extraídos para NRTQ:
# CNPJ: 29.950.060/0001-57
# Setor NAICS3: indústria de remédios
# Subsetor Bovespa: medicamentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 72685.62
# - Capital total médio: 72685.62
#
# Estatísticas do carregamento:
# Períodos: 48
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 77669.44
# - Trabalho indireto médio: 13980.21
# - Insumo variável médio: 91649.65
# Empresa NRTQ processada com sucesso
#
# Dados extraídos para NUTR:
# CNPJ: 51.128.999/0001-90
# Setor NAICS3: indústria de fertilizantes e pesticidas
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 4357.37
# - Capital total médio: 4357.37
#
# Estatísticas do carregamento:
# Períodos: 71
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 31058.03
# - Trabalho indireto médio: 2635.66
# - Insumo variável médio: 33693.69
# Empresa NUTR processada com sucesso
#
# Dados extraídos para ODER:
# CNPJ: 97.191.902/0001-94
# Setor NAICS3: indústria de frutas e vegetais em conserva e comidas especiais
# Subsetor Bovespa: alimentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 80110.90
# - Capital total médio: 80110.90
#
# Estatísticas do carregamento:
# Períodos: 106
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 136643.94
# - Trabalho indireto médio: 11243.65
# - Insumo variável médio: 147887.59
# Empresa ODER processada com sucesso
#
# Dados extraídos para OFSA:
# CNPJ: 20.258.278/0001-70
# Setor NAICS3: indústria de remédios
# Subsetor Bovespa: medicamentos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# ...
# Composição do insumo variável:
# - COGS médio: 3362066.11
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa TTEN processada com sucesso
#
# Dados extraídos para TUPY:
# CNPJ: 84.683.374/0001-49
# Setor NAICS3: indústria de autopeças
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 410013.50
# - Capital total médio: 410013.50
#
# Estatísticas do carregamento:
# Períodos: 150
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 571861.09
# - Trabalho indireto médio: 31566.03
# - Insumo variável médio: 603427.12
# Empresa TUPY processada com sucesso
#
# Dados extraídos para TXRX:
# CNPJ: 82.982.075/0001-80
# Setor NAICS3: tecelagens
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 54828.45
# - Capital total médio: 54828.45
#
# Estatísticas do carregamento:
# Períodos: 146
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 36652.39
# - Trabalho indireto médio: 4176.28
# - Insumo variável médio: 40828.67
# Empresa TXRX processada com sucesso
#
# Dados extraídos para UNIP:
# CNPJ: 33.958.695/0001-78
# Setor NAICS3: -
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 286436.64
# - Capital total médio: 286436.64
#
# Estatísticas do carregamento:
# Períodos: 149
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 156414.72
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa UNIP processada com sucesso
#
# Dados extraídos para USIM:
# CNPJ: 60.894.730/0001-05
# Setor NAICS3: transformação de aço em produtos de aço
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 6595776.55
# - Capital total médio: 6595776.55
#
# Estatísticas do carregamento:
# Períodos: 138
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 4285972.10
# - Trabalho indireto médio: 121440.12
# - Insumo variável médio: 4407412.22
# Empresa USIM processada com sucesso
#
# Dados extraídos para VALE:
# CNPJ: 33.592.510/0001-54
# Setor NAICS3: mineração de metais
# Subsetor Bovespa: não classificado
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 43987579.76
# - Capital total médio: 43987579.76
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 10516209.16
# - Trabalho indireto médio: 461587.85
# - Insumo variável médio: 10977797.01
# Empresa VALE processada com sucesso
#
# Dados extraídos para VITT:
# CNPJ: 45.365.558/0001-09
# Setor NAICS3: atividades auxiliares à agricultura
# Subsetor Bovespa: químicos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 189160.27
# - Capital total médio: 189160.27
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 213385.45
# - Trabalho indireto médio: 41752.36
# - Insumo variável médio: 255137.82
# Empresa VITT processada com sucesso
#
# Dados extraídos para VIVA:
# CNPJ: 33.839.910/0001-11
# Setor NAICS3: loja de jóias, malas e artigos de couro
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 0.00
# - Capital total médio: 0.00
#
# Estatísticas do carregamento:
# Períodos: 22
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 0.00
# - Trabalho indireto médio: 6100.45
# - Insumo variável médio: 6100.45
# Empresa VIVA processada com sucesso
#
# Dados extraídos para VIVT:
# CNPJ: 02.558.157/0001-62
# Setor NAICS3: -
# Subsetor Bovespa: telecomunicações
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 16739833.68
# - Capital total médio: 16739833.68
#
# Estatísticas do carregamento:
# Períodos: 148
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 5781275.30
# - Trabalho indireto médio: 673758.17
# - Insumo variável médio: 6455033.48
# Erro na consolidação e mapeamento: 'DataLoader' object has no attribute 'naics_para_ipa'
#
# Dados extraídos para VULC:
# CNPJ: 50.926.955/0001-42
# Setor NAICS3: indústria de calçados
# Subsetor Bovespa: tecidos
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 3543.17
# - Capital total médio: 3543.17
#
# Estatísticas do carregamento:
# Períodos: 147
# Observações válidas: 2
# Composição do insumo variável:
# - COGS médio: 4356.70
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa VULC processada com sucesso
#
# Dados extraídos para WEGE:
# CNPJ: 84.429.695/0001-11
# Setor NAICS3: indústria de motores, turbinas e transmissores de energia
# Subsetor Bovespa: máquinas
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: nan
# - Capital total médio: 3624.25
#
# Estatísticas do carregamento:
# Períodos: 149
# Observações válidas: 0
# Composição do insumo variável:
# - COGS médio: nan
# - Trabalho indireto médio: nan
# - Insumo variável médio: nan
# Empresa WEGE processada com sucesso
#
# Dados extraídos para WHRL:
# CNPJ: 59.105.999/0001-86
# Setor NAICS3: indústria de eletrodomésticos
# Subsetor Bovespa: utilidades
# 2025-03-05 16:36:02,527 - INFO -
# Missing value summary:
# 2025-03-05 16:36:02,528 - INFO - cnpj: 382 missing values (3.6%)
# 2025-03-05 16:36:02,529 - INFO - variable_input: 70 missing values (0.7%)
# 2025-03-05 16:36:02,531 - INFO - capital: 441 missing values (4.1%)
# 2025-03-05 16:36:02,533 - INFO - receita: 1629 missing values (15.3%)
# 2025-03-05 16:36:02,534 - INFO -
# Variable input calculation:
# 2025-03-05 16:36:02,536 - INFO - Invalid/missing values: 70
# 2025-03-05 16:36:02,537 - INFO - Raw data loaded:
# 2025-03-05 16:36:02,537 - INFO - Total observations: 10651
# 2025-03-05 16:36:02,541 - INFO - Unique firms: 107
# 2025-03-05 16:36:02,543 - INFO - Time period: 1986-03 to 2024-12
# 2025-03-05 16:36:02,545 - INFO - Loading price indices and applying deflation...
# Encontrado receita com padrão: Receita liquida
# Encontrado cogs com padrão: Custo Produtos
# Encontrado trabalho_indireto com padrão: Despesas admin
# Encontrado imobilizado com padrão: Imobilizado
# Composição do capital:
# - Imobilizado médio: 621448.17
# - Capital total médio: 621448.17
#
# Estatísticas do carregamento:
# Períodos: 123
# Observações válidas: 3
# Composição do insumo variável:
# - COGS médio: 2190375.21
# - Trabalho indireto médio: 121495.78
# - Insumo variável médio: 2311870.98
# Empresa WHRL processada com sucesso
# Removing 1605 non-positive values from receita
# Removing 427 non-positive values from capital
# Error in data cleaning: ['cogs', 'trabalho_indireto']
# 2025-03-05 16:36:11,776 - WARNING - Variable imobilizado not found in dataset
# 2025-03-05 16:36:16,060 - WARNING - Variable cogs not found in dataset
# 2025-03-05 16:36:16,060 - WARNING - Variable trabalho_indireto not found in dataset
# 2025-03-05 16:36:16,061 - WARNING - 31 null values in deflated variable_input
# 2025-03-05 16:36:16,063 - WARNING - 430 null values in deflated capital
# 2025-03-05 16:36:16,066 - WARNING - 1600 null values in deflated receita
# 2025-03-05 16:36:16,070 - INFO - Performing sector aggregation...
# 2025-03-05 16:36:16,072 - INFO - Iniciando agregação setorial...
# 2025-03-05 16:36:16,074 - INFO - Mapeando códigos setoriais...
# 2025-03-05 16:36:16,091 - INFO - Setores originais: 39
# 2025-03-05 16:36:16,092 - INFO - Setores após agregação: 11
# 2025-03-05 16:36:16,099 - INFO -
# Mapeamento de setores:
# 2025-03-05 16:36:16,100 - INFO - 201101000 -> 2011010 (Agricultura e pecuária)
# 2025-03-05 16:36:16,103 - INFO - 202106000 -> 2021060 (Indústria extrativa, inclusive petróleo e gás natural)
# 2025-03-05 16:36:16,104 - INFO - 202107000 -> 2021060 (Indústria extrativa, inclusive petróleo e gás natural)
# 2025-03-05 16:36:16,106 - INFO - 202107200 -> 2021060 (Indústria extrativa, inclusive petróleo e gás natural)
# 2025-03-05 16:36:16,106 - INFO - 202210100 -> 2022100 (Alimentos e bebidas)
# 2025-03-05 16:36:16,108 - INFO - 202210300 -> 2022100 (Alimentos e bebidas)
# 2025-03-05 16:36:16,110 - INFO - 202210700 -> 2022100 (Alimentos e bebidas)
# 2025-03-05 16:36:16,110 - INFO - 202210900 -> 2022100 (Alimentos e bebidas)
# 2025-03-05 16:36:16,112 - INFO - 202211000 -> 2022100 (Alimentos e bebidas)
# 2025-03-05 16:36:16,114 - INFO - 202213000 -> 2022130 (Têxteis, vestuário, couro e calçados)
# 2025-03-05 16:36:16,117 - INFO - 202214000 -> 2022130 (Têxteis, vestuário, couro e calçados)
# 2025-03-05 16:36:16,118 - INFO - 202215000 -> 2022130 (Têxteis, vestuário, couro e calçados)
# 2025-03-05 16:36:16,120 - INFO - 202216000 -> 2022160 (Madeira, celulose e papel)
# 2025-03-05 16:36:16,121 - INFO - 202217100 -> 2022160 (Madeira, celulose e papel)
# 2025-03-05 16:36:16,122 - INFO - 202217300 -> 2022160 (Madeira, celulose e papel)
# 2025-03-05 16:36:16,123 - INFO - 202217900 -> 2022160 (Madeira, celulose e papel)
# 2025-03-05 16:36:16,127 - INFO - 202219200 -> 2022190 (Produtos derivados do petróleo e biocombustíveis)
# 2025-03-05 16:36:16,127 - INFO - 202219300 -> 2022190 (Produtos derivados do petróleo e biocombustíveis)
# 2025-03-05 16:36:16,129 - INFO - 202219900 -> 2022190 (Produtos derivados do petróleo e biocombustíveis)
# 2025-03-05 16:36:16,131 - INFO - 202220100 -> 2022200 (Indústria química, exceto petroquímica)
# 2025-03-05 16:36:16,133 - INFO - 202220500 -> 2022200 (Indústria química, exceto petroquímica)
# 2025-03-05 16:36:16,135 - INFO - 202221200 -> 2022210 (Indústria farmacêutica)
# 2025-03-05 16:36:16,136 - INFO - 202223300 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,138 - INFO - 202223400 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,140 - INFO - 202224200 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,141 - INFO - 202224400 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,143 - INFO - 202225300 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,144 - INFO - 202225900 -> 2022240 (Metalurgia, siderurgia e produtos de minerais não-metálicos)
# 2025-03-05 16:36:16,145 - INFO - 202226200 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,146 - INFO - 202227500 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,147 - INFO - 202227900 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,147 - INFO - 202228100 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,149 - INFO - 202228200 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,154 - INFO - 202228300 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,155 - INFO - 202228400 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,155 - INFO - 202228600 -> 2022270 (Máquinas, equipamentos e aparelhos diversos)
# 2025-03-05 16:36:16,157 - INFO - 202229300 -> 2022290 (Veículos automotores e e outros equipamentos de transporte)
# 2025-03-05 16:36:16,157 - INFO - 202229400 -> 2022290 (Veículos automotores e e outros equipamentos de transporte)
# 2025-03-05 16:36:16,159 - INFO - 202230100 -> 2022290 (Veículos automotores e e outros equipamentos de transporte)
# 2025-03-05 16:36:16,160 - INFO - Saving processed datasets...
# 2025-03-05 16:36:16,161 - INFO -
# Setor aggregation results:
# 2025-03-05 16:36:16,162 - INFO - Original sectors (setor_ipa): 39
# 2025-03-05 16:36:16,164 - INFO - Aggregated sectors (setor_ipa_7d): 11
# 2025-03-05 16:36:34,104 - INFO -
# Final Dataset Summary:
# 2025-03-05 16:36:34,105 - INFO - Total observations: 10360
# 2025-03-05 16:36:34,107 - INFO - Unique firms: 107
# 2025-03-05 16:36:34,109 - INFO - Original IPA sectors: 39
# 2025-03-05 16:36:34,111 - INFO - Aggregated sectors: 11
# 2025-03-05 16:36:34,118 - INFO -
# Data Quality Metrics:
# 2025-03-05 16:36:34,119 - INFO - Missing rate for cnpj: 3.5%
# 2025-03-05 16:36:34,120 - INFO - Missing rate for variable_input: 0.3%
# 2025-03-05 16:36:34,121 - INFO - Missing rate for capital: 4.2%
# 2025-03-05 16:36:34,121 - INFO - Missing rate for receita: 15.4%
# 2025-03-05 16:36:34,124 - INFO - Missing rate for variable_input_nominal: 0.3%
# 2025-03-05 16:36:34,125 - INFO - Missing rate for capital_nominal: 4.2%
# 2025-03-05 16:36:34,126 - INFO - Missing rate for receita_nominal: 15.4%
# 2025-03-05 16:36:34,128 - INFO - Processing completed successfully!
# Resumo por Setor:
#                                                       setor  empresas  observacoes receita_media receita_desvio input_var_medio input_var_desvio capital_medio capital_desvio
#                                      Agricultura e pecuária         8          338    814,018.27   1,418,095.03      609,706.48     1,089,476.89    544,526.48   1,167,962.84
#       Indústria extrativa, inclusive petróleo e gás natural         9          604 39,434,596.92  77,640,890.25   17,603,681.59    41,115,053.50 65,953,135.45 158,709,241.85
#                                         Alimentos e bebidas        13         1167  4,723,543.68   8,122,231.16    2,984,515.04     6,189,882.86  2,579,916.27   3,951,854.86
#                        Têxteis, vestuário, couro e calçados        18         1952    238,381.99     408,034.40      149,933.86       249,773.56    126,134.23     176,507.90
#                                   Madeira, celulose e papel         7          815  1,920,329.85   4,035,764.58    1,078,045.00     2,639,051.99  3,632,570.29   9,022,739.75
#            Produtos derivados do petróleo e biocombustíveis         4          290 12,245,031.83  22,244,734.35   11,335,480.68    21,091,397.90  5,591,799.83   7,355,577.43
#                      Indústria química, exceto petroquímica         5          447    597,298.93   1,095,510.82      501,246.49       991,315.36    233,693.68     279,665.25
#                                      Indústria farmacêutica         3          181     68,728.69      66,098.16       39,348.44        50,977.49     65,466.05      64,982.91
# Metalurgia, siderurgia e produtos de minerais não-metálicos        17         2107  1,201,641.54   2,898,848.82      805,181.55     2,250,382.47  1,190,424.40   2,987,032.44
#                 Máquinas, equipamentos e aparelhos diversos        15         1378    547,795.74   1,138,977.45      407,774.68       930,992.46    139,107.70     202,031.34
#  Veículos automotores e e outros equipamentos de transporte         8         1081    926,372.27   2,056,443.29      734,980.53     1,692,435.20    342,648.25     741,096.36
#
# Results saved in: C:\Users\fabio\OneDrive\Projeto_Markup\Results\Model3\v1
